# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as streamlit
import pandas as pandas
import numpy as numpy

# %% [markdown]
# ### Title

# %%
streamlit.title('Webcrawler')
# Out:
# 2026-03-27 15:31:09.827 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-27 15:31:10.870
# ...
#   command:
#
#     streamlit run C:\Users\josef\anaconda3\envs\pictureEdit\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-03-27 15:31:10.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-27 15:31:10.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
